# %%
from tello_sim import swarm_simulator
swarm = swarm_simulator.Swarm()
# Out:
# Hi! I am Drone_1.
# I am now ready to take off. 🚁
# I am running your "command" command.
# Hi! I am Drone_2.
# I am now ready to take off. 🚁
# I am running your "command" command.
# Hi! I am Drone_3.
# I am now ready to take off. 🚁
# I am running your "command" command.

# %%
swarm.swarm_takeoff()

# %%
swarm.swarm_up(50, 25, 0)
# Out:
# Get ready for takeoff!
# I am running your "takeoff" command.
# My estimated takeoff altitude is 81 centimeters
# Get ready for takeoff!
# I am running your "takeoff" command.
# My estimated takeoff altitude is 81 centimeters

# %%
swarm.swarm_left(40, 0, 0)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "forward 35" command.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "cw 40" command.
# My new bearing is 40 degrees.

# %%
swarm.swarm_right(0, 35, 0)
# Out:
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "down 25" command.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 40 degrees.
# I am running your "forward 35" command.

# %%
swarm.swarm_ccw(0, 0, 45)
# Out:
# I am flying at 56 centimeters above my takeoff altitude.
# My current bearing is 0 degrees.
# I am running your "cw 9" command.
# My new bearing is 9 degrees.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 40 degrees.
# I am running your "cw 90" command.
# My new bearing is 130 degrees.

# %%
swarm.swarm_forward(0, 60, 60)
# Out:
# I am flying at 56 centimeters above my takeoff altitude.
# My current bearing is 9 degrees.
# I am running your "forward 100" command.
# I am flying at 81 centimeters above my takeoff altitude.
# My current bearing is 130 degrees.
# I am running your "forward 50" command.

# %%
swarm.swarm_flip("f", "", "r")
# Out:
# I am flying at 56 centimeters above my takeoff altitude.
# My current bearing is 9 degrees.
# I am running your "right 100" command.

# %%
swarm.swarm_down(20, 0, 5)
# Out:
# I am flying at 56 centimeters above my takeoff altitude.
# I am running your "flip f" command.

# %%
swarm.swarm_forward(35, 60, 80)
# Out:
# I am flying at 56 centimeters above my takeoff altitude.
# My current bearing is 9 degrees.
# I am running your "forward 100" command.

# %%
swarm.swarm_land()
# Out:
# Get ready for landing!
# I am flying at 56 centimeters above my takeoff altitude.
# I am running your "land" command.
# Here are the graphs of your flight! I can't wait to try this for real.
